# %% [markdown]
# # Import Dependencies

# %%
import pandas as pd
import os
from datetime import datetime
import numpy as np

# %% [markdown]
# # Read Video Games Data from CSV

# %%
# Set CSV file path
path = os.path.join('Output', 'Extracted_video_games_data.csv')

# %%
# Read games data from CSV file into Dataframe
games_df = pd.read_csv(path)
games_df
# Out:
#        Pos  Game                           Game.1 Console  \
# 0        1   NaN                       God of War  Series
# 1        2   NaN                         Warriors  Series
# 2        3   NaN                    Devil May Cry  Series
# 3        4   NaN                 Dynasty Warriors  Series
# 4        5   NaN               Grand Theft Auto V     PS3
# ...    ...   ...                              ...     ...
# 58892  436   NaN               World End Syndrome     PS4
# 58893  437   NaN            XBlaze Lost: Memories      PC
# 58894  438   NaN                     Yoru, Tomosu      NS
# 58895  439   NaN                     Yoru, Tomosu     PS4
# 58896  440   NaN  Yunohana SpRING! ~Mellow Times~      NS
#
#                          Publisher                Developer  VGChartz Score  \
# 0      Sony Computer Entertainment  SIE Santa Monica Studio             NaN
# 1                             KOEI              Omega Force             NaN
# 2                           Capcom                   Capcom             NaN
# 3                          Unknown              Omega Force             NaN
# 4                   Rockstar Games           Rockstar North             NaN
# ...                            ...                      ...             ...
# 58892             Arc System Works         Arc System Works             NaN
# 58893                  Aksys Games         Arc System Works             NaN
# 58894         Nippon Ichi Software     Nippon Ichi Software             NaN
# 58895         Nippon Ichi Software     Nippon Ichi Software             NaN
# 58896                 Idea Factory                  Otomate             NaN
#
#        Critic Score  User Score Total Shipped Total Sales NA Sales PAL Sales  \
# 0               NaN         NaN        51.00m         NaN      NaN       NaN
# 1               NaN         NaN        45.26m         NaN      NaN       NaN
# 2               NaN         NaN        22.00m         NaN      NaN       NaN
# 3               NaN         NaN        21.00m         NaN      NaN       NaN
# 4               9.4         NaN           NaN      20.32m    6.37m     9.85m
# ...             ...         ...           ...         ...      ...       ...
# 58892           NaN         NaN           NaN         NaN      NaN       NaN
# 58893           NaN         NaN           NaN         NaN      NaN       NaN
# 58894           NaN         NaN           NaN         NaN      NaN       NaN
# 58895           NaN         NaN           NaN         NaN      NaN       NaN
# 58896           NaN         NaN           NaN         NaN      NaN       NaN
#
#       Japan Sales Other Sales Release Date  Last Update         Genre
# 0             NaN         NaN  22nd Mar 05  04th Mar 20        Action
# 1             NaN         NaN  30th Jun 97  24th Mar 20        Action
# 2             NaN         NaN  16th Oct 01  03rd Feb 20        Action
# 3             NaN         NaN          NaN  24th Mar 20        Action
# 4           0.99m       3.12m  17th Sep 13          NaN        Action
# ...           ...         ...          ...          ...           ...
# 58892         NaN         NaN  26th Apr 18  03rd Apr 19  Visual Novel
# 58893         NaN         NaN  11th Aug 16  28th Jan 19  Visual Novel
# 58894         NaN         NaN  30th Jul 20  09th May 20  Visual Novel
# 58895         NaN         NaN  30th Jul 20  09th May 20  Visual Novel
# 58896         NaN         NaN  28th Feb 19  24th Feb 19  Visual Novel
#
# [58897 rows x 18 columns]

# %% [markdown]
# # Delete games without sales data

# %%
# Find number of games without sales data
len(games_df.loc[games_df['NA Sales'].isna() &
                 games_df['PAL Sales'].isna() &
                 games_df['Japan Sales'].isna() &
                 games_df['Other Sales'].isna() &
                 games_df['Total Sales'].isna() &
                 games_df['Total Shipped'].isna()])
# Out:
# 36795

# %%
# Determine how many games have some sales data
len(games_df) - len(games_df.loc[games_df['NA Sales'].isna() &
                    games_df['PAL Sales'].isna() &
                    games_df['Japan Sales'].isna() &
                    games_df['Other Sales'].isna() &
                    games_df['Total Sales'].isna() &
                    games_df['Total Shipped'].isna()])
# Out:
# 22102

# %%
# Eliminate games without sales data
cleaned_df = games_df.loc[games_df['NA Sales'].notna() |
                          games_df['PAL Sales'].notna() |
                          games_df['Japan Sales'].notna() |
                          games_df['Other Sales'].notna() |
                          games_df['Total Sales'].notna() |
                          games_df['Total Shipped'].notna()]
len(cleaned_df)
# Out:
# 22102

# %%
cleaned_df
# Out:
#        Pos  Game                             Game.1 Console  \
# 0        1   NaN                         God of War  Series
# 1        2   NaN                           Warriors  Series
# 2        3   NaN                      Devil May Cry  Series
# 3        4   NaN                   Dynasty Warriors  Series
# 4        5   NaN                 Grand Theft Auto V     PS3
# ...    ...   ...                                ...     ...
# 58688  232   NaN      Nora, Princess, and Stray Cat      NS
# 58689  233   NaN        Memories Off: Innocent File      NS
# 58690  234   NaN   Enkan no Memoria: Kakera Tomoshi     PSV
# 58691  235   NaN                         Disorder 6    X360
# 58692  236   NaN  Zero Escape: Virtue's Last Reward     PSV
#
#                          Publisher                Developer  VGChartz Score  \
# 0      Sony Computer Entertainment  SIE Santa Monica Studio             NaN
# 1                             KOEI              Omega Force             NaN
# 2                           Capcom                   Capcom             NaN
# 3                          Unknown              Omega Force             NaN
# 4                   Rockstar Games           Rockstar North             NaN
# ...                            ...                      ...             ...
# 58688                     Harukaze                 Harukaze             NaN
# 58689                          5pb               5pb. Games             NaN
# 58690              Dramatic Create                  A'sRing             NaN
# 58691                          5pb               5pb. Games             NaN
# 58692                  Aksys Games                 ChunSoft             NaN
#
#        Critic Score  User Score Total Shipped Total Sales NA Sales PAL Sales  \
# 0               NaN         NaN        51.00m         NaN      NaN       NaN
# 1               NaN         NaN        45.26m         NaN      NaN       NaN
# 2               NaN         NaN        22.00m         NaN      NaN       NaN
# 3               NaN         NaN        21.00m         NaN      NaN       NaN
# 4               9.4         NaN           NaN      20.32m    6.37m     9.85m
# ...             ...         ...           ...         ...      ...       ...
# 58688           NaN         NaN           NaN       0.00m      NaN       NaN
# 58689           NaN         NaN           NaN       0.00m      NaN       NaN
# 58690           NaN         NaN           NaN       0.00m      NaN       NaN
# 58691           NaN         NaN           NaN       0.00m      NaN       NaN
# 58692           NaN         NaN           NaN       0.00m      NaN     0.00m
#
#       Japan Sales Other Sales Release Date  Last Update         Genre
# 0             NaN         NaN  22nd Mar 05  04th Mar 20        Action
# 1             NaN         NaN  30th Jun 97  24th Mar 20        Action
# 2             NaN         NaN  16th Oct 01  03rd Feb 20        Action
# 3             NaN         NaN          NaN  24th Mar 20        Action
# 4           0.99m       3.12m  17th Sep 13          NaN        Action
# ...           ...         ...          ...          ...           ...
# 58688       0.00m         NaN  25th Oct 18  07th Nov 18  Visual Novel
# 58689       0.00m         NaN  25th Oct 18  07th Nov 18  Visual Novel
# 58690       0.00m         NaN  29th Mar 18  07th Apr 18  Visual Novel
# 58691       0.00m         NaN  22nd Aug 13  02nd May 19  Visual Novel
# 58692         NaN       0.00m  23rd Oct 12  25th Apr 19  Visual Novel
#
# [22102 rows x 18 columns]

# %% [markdown]
# # Delete unwanted columns

# %%
cleaned_df.columns
# Out:
# Index(['Pos', 'Game', 'Game.1', 'Console', 'Publisher', 'Developer',
#        'VGChartz Score', 'Critic Score', 'User Score', 'Total Shipped',
#        'Total Sales', 'NA Sales', 'PAL Sales', 'Japan Sales', 'Other Sales',
#        'Release Date', 'Last Update', 'Genre'],
#       dtype='object')

# %%
# Check if data exists in Game column
len(cleaned_df.loc[cleaned_df['Game'].notna()])
# Out:
# 0

# %%
# Removing game and last update columns
cleaned_df = cleaned_df[['Pos',
                         'Game.1',
                         'Console',
                         'Publisher',
                         'Developer',
                         'VGChartz Score',
                         'Critic Score',
                         'User Score',
                         'Total Shipped',
                         'Total Sales',
                         'NA Sales',
                         'PAL Sales',
                         'Japan Sales',
                         'Other Sales',
                         'Release Date',
                         'Genre']]

# %%
cleaned_df.columns
# Out:
# Index(['Pos', 'Game.1', 'Console', 'Publisher', 'Developer', 'VGChartz Score',
#        'Critic Score', 'User Score', 'Total Shipped', 'Total Sales',
#        'NA Sales', 'PAL Sales', 'Japan Sales', 'Other Sales', 'Release Date',
#        'Genre'],
#       dtype='object')

# %% [markdown]
# # Rename columns

# %%
# Rename columns
renamed_df = cleaned_df.rename(columns={
    'Pos' : 'rank', 
    'Game.1' : 'game_name',
    'Console' : 'console',
    'Publisher' : 'publisher',
    'Developer' : 'developer',
    'VGChartz Score' : 'vgchartz_score',
    'Critic Score' : 'critic_score',
    'User Score' : 'user_score',
    'Total Shipped' : 'total_shipped',
    'Total Sales' : 'global_sales',
    'NA Sales' : 'na_sales',
    'PAL Sales' : 'pal_sales',
    'Japan Sales' : 'japan_sales',
    'Other Sales' : 'other_sales',
    'Release Date' : 'release_date',
    'Genre' : 'genre'
})
renamed_df
# Out:
#        rank                          game_name console  \
# 0         1                         God of War  Series
# 1         2                           Warriors  Series
# 2         3                      Devil May Cry  Series
# 3         4                   Dynasty Warriors  Series
# 4         5                 Grand Theft Auto V     PS3
# ...     ...                                ...     ...
# 58688   232      Nora, Princess, and Stray Cat      NS
# 58689   233        Memories Off: Innocent File      NS
# 58690   234   Enkan no Memoria: Kakera Tomoshi     PSV
# 58691   235                         Disorder 6    X360
# 58692   236  Zero Escape: Virtue's Last Reward     PSV
#
#                          publisher                developer  vgchartz_score  \
# 0      Sony Computer Entertainment  SIE Santa Monica Studio             NaN
# 1                             KOEI              Omega Force             NaN
# 2                           Capcom                   Capcom             NaN
# 3                          Unknown              Omega Force             NaN
# 4                   Rockstar Games           Rockstar North             NaN
# ...                            ...                      ...             ...
# 58688                     Harukaze                 Harukaze             NaN
# 58689                          5pb               5pb. Games             NaN
# 58690              Dramatic Create                  A'sRing             NaN
# 58691                          5pb               5pb. Games             NaN
# 58692                  Aksys Games                 ChunSoft             NaN
#
#        critic_score  user_score total_shipped global_sales na_sales pal_sales  \
# 0               NaN         NaN        51.00m          NaN      NaN       NaN
# 1               NaN         NaN        45.26m          NaN      NaN       NaN
# 2               NaN         NaN        22.00m          NaN      NaN       NaN
# 3               NaN         NaN        21.00m          NaN      NaN       NaN
# 4               9.4         NaN           NaN       20.32m    6.37m     9.85m
# ...             ...         ...           ...          ...      ...       ...
# 58688           NaN         NaN           NaN        0.00m      NaN       NaN
# 58689           NaN         NaN           NaN        0.00m      NaN       NaN
# 58690           NaN         NaN           NaN        0.00m      NaN       NaN
# 58691           NaN         NaN           NaN        0.00m      NaN       NaN
# 58692           NaN         NaN           NaN        0.00m      NaN     0.00m
#
#       japan_sales other_sales release_date         genre
# 0             NaN         NaN  22nd Mar 05        Action
# 1             NaN         NaN  30th Jun 97        Action
# 2             NaN         NaN  16th Oct 01        Action
# 3             NaN         NaN          NaN        Action
# 4           0.99m       3.12m  17th Sep 13        Action
# ...           ...         ...          ...           ...
# 58688       0.00m         NaN  25th Oct 18  Visual Novel
# 58689       0.00m         NaN  25th Oct 18  Visual Novel
# 58690       0.00m         NaN  29th Mar 18  Visual Novel
# 58691       0.00m         NaN  22nd Aug 13  Visual Novel
# 58692         NaN       0.00m  23rd Oct 12  Visual Novel
#
# [22102 rows x 16 columns]

# %% [markdown]
# # Add Release Year Column

# %%
# Add release year column

renamed_df['release_year'] = np.NaN

current_year = int(datetime.now().strftime('%y'))

for index, row in renamed_df.loc[renamed_df['release_date'].notna()].iterrows():
    release_dt = row[14]
    year = release_dt.split(' ')[2]
    if int(year) <= current_year:
        release_year = '20' + year
    else:
        release_year = '19' + year
    renamed_df.loc[index, 'release_year'] = release_year

renamed_df
# Out:
#        rank                          game_name console  \
# 0         1                         God of War  Series
# 1         2                           Warriors  Series
# 2         3                      Devil May Cry  Series
# 3         4                   Dynasty Warriors  Series
# 4         5                 Grand Theft Auto V     PS3
# ...     ...                                ...     ...
# 58688   232      Nora, Princess, and Stray Cat      NS
# 58689   233        Memories Off: Innocent File      NS
# 58690   234   Enkan no Memoria: Kakera Tomoshi     PSV
# 58691   235                         Disorder 6    X360
# 58692   236  Zero Escape: Virtue's Last Reward     PSV
#
#                          publisher                developer  vgchartz_score  \
# 0      Sony Computer Entertainment  SIE Santa Monica Studio             NaN
# 1                             KOEI              Omega Force             NaN
# 2                           Capcom                   Capcom             NaN
# 3                          Unknown              Omega Force             NaN
# 4                   Rockstar Games           Rockstar North             NaN
# ...                            ...                      ...             ...
# 58688                     Harukaze                 Harukaze             NaN
# 58689                          5pb               5pb. Games             NaN
# 58690              Dramatic Create                  A'sRing             NaN
# 58691                          5pb               5pb. Games             NaN
# 58692                  Aksys Games                 ChunSoft             NaN
#
#        critic_score  user_score total_shipped global_sales na_sales pal_sales  \
# 0               NaN         NaN        51.00m          NaN      NaN       NaN
# 1               NaN         NaN        45.26m          NaN      NaN       NaN
# 2               NaN         NaN        22.00m          NaN      NaN       NaN
# 3               NaN         NaN        21.00m          NaN      NaN       NaN
# 4               9.4         NaN           NaN       20.32m    6.37m     9.85m
# ...             ...         ...           ...          ...      ...       ...
# 58688           NaN         NaN           NaN        0.00m      NaN       NaN
# 58689           NaN         NaN           NaN        0.00m      NaN       NaN
# 58690           NaN         NaN           NaN        0.00m      NaN       NaN
# 58691           NaN         NaN           NaN        0.00m      NaN       NaN
# 58692           NaN         NaN           NaN        0.00m      NaN     0.00m
#
#       japan_sales other_sales release_date         genre release_year
# 0             NaN         NaN  22nd Mar 05        Action         2005
# 1             NaN         NaN  30th Jun 97        Action         1997
# 2             NaN         NaN  16th Oct 01        Action         2001
# 3             NaN         NaN          NaN        Action          NaN
# 4           0.99m       3.12m  17th Sep 13        Action         2013
# ...           ...         ...          ...           ...          ...
# 58688       0.00m         NaN  25th Oct 18  Visual Novel         2018
# 58689       0.00m         NaN  25th Oct 18  Visual Novel         2018
# 58690       0.00m         NaN  29th Mar 18  Visual Novel         2018
# 58691       0.00m         NaN  22nd Aug 13  Visual Novel         2013
# 58692         NaN       0.00m  23rd Oct 12  Visual Novel         2012
#
# [22102 rows x 17 columns]

# %%
# Check the release year data type
renamed_df.dtypes
# Out:
# rank                int64
# game_name          object
# console            object
# publisher          object
# developer          object
# vgchartz_score    float64
# critic_score      float64
# user_score        float64
# total_shipped      object
# global_sales       object
# na_sales           object
# pal_sales          object
# japan_sales        object
# other_sales        object
# release_date       object
# genre              object
# release_year       object
# dtype: object

# %%
# Convert release year to float data type
renamed_df['release_year'] = renamed_df['release_year'].astype('float64')

# %%
# Convert release year to Int data type
renamed_df['release_year'] = renamed_df['release_year'].astype('Int32')

# %%
# Confirm release year Int
renamed_df.dtypes
# Out:
# rank                int64
# game_name          object
# console            object
# publisher          object
# developer          object
# vgchartz_score    float64
# critic_score      float64
# user_score        float64
# total_shipped      object
# global_sales       object
# na_sales           object
# pal_sales          object
# japan_sales        object
# other_sales        object
# release_date       object
# genre              object
# release_year        Int32
# dtype: object

# %%
# Check the release year column values
renamed_df
# Out:
#        rank                          game_name console  \
# 0         1                         God of War  Series
# 1         2                           Warriors  Series
# 2         3                      Devil May Cry  Series
# 3         4                   Dynasty Warriors  Series
# 4         5                 Grand Theft Auto V     PS3
# ...     ...                                ...     ...
# 58688   232      Nora, Princess, and Stray Cat      NS
# 58689   233        Memories Off: Innocent File      NS
# 58690   234   Enkan no Memoria: Kakera Tomoshi     PSV
# 58691   235                         Disorder 6    X360
# 58692   236  Zero Escape: Virtue's Last Reward     PSV
#
#                          publisher                developer  vgchartz_score  \
# 0      Sony Computer Entertainment  SIE Santa Monica Studio             NaN
# 1                             KOEI              Omega Force             NaN
# 2                           Capcom                   Capcom             NaN
# 3                          Unknown              Omega Force             NaN
# 4                   Rockstar Games           Rockstar North             NaN
# ...                            ...                      ...             ...
# 58688                     Harukaze                 Harukaze             NaN
# 58689                          5pb               5pb. Games             NaN
# 58690              Dramatic Create                  A'sRing             NaN
# 58691                          5pb               5pb. Games             NaN
# 58692                  Aksys Games                 ChunSoft             NaN
#
#        critic_score  user_score total_shipped global_sales na_sales pal_sales  \
# 0               NaN         NaN        51.00m          NaN      NaN       NaN
# 1               NaN         NaN        45.26m          NaN      NaN       NaN
# 2               NaN         NaN        22.00m          NaN      NaN       NaN
# 3               NaN         NaN        21.00m          NaN      NaN       NaN
# 4               9.4         NaN           NaN       20.32m    6.37m     9.85m
# ...             ...         ...           ...          ...      ...       ...
# 58688           NaN         NaN           NaN        0.00m      NaN       NaN
# 58689           NaN         NaN           NaN        0.00m      NaN       NaN
# 58690           NaN         NaN           NaN        0.00m      NaN       NaN
# 58691           NaN         NaN           NaN        0.00m      NaN       NaN
# 58692           NaN         NaN           NaN        0.00m      NaN     0.00m
#
#       japan_sales other_sales release_date         genre  release_year
# 0             NaN         NaN  22nd Mar 05        Action          2005
# 1             NaN         NaN  30th Jun 97        Action          1997
# 2             NaN         NaN  16th Oct 01        Action          2001
# 3             NaN         NaN          NaN        Action          <NA>
# 4           0.99m       3.12m  17th Sep 13        Action          2013
# ...           ...         ...          ...           ...           ...
# 58688       0.00m         NaN  25th Oct 18  Visual Novel          2018
# 58689       0.00m         NaN  25th Oct 18  Visual Novel          2018
# 58690       0.00m         NaN  29th Mar 18  Visual Novel          2018
# 58691       0.00m         NaN  22nd Aug 13  Visual Novel          2013
# 58692         NaN       0.00m  23rd Oct 12  Visual Novel          2012
#
# [22102 rows x 17 columns]

# %% [markdown]
# # Convert Release date values to Date format (yyyy-mm-dd)

# %%
# Convert release date values to date format
for index, row in renamed_df.loc[renamed_df['release_date'].notna()].iterrows():
    release_dt = row[14]
    release_date = release_dt[:2]+release_dt[4:]
    formatted_release_date = datetime.strptime(release_date, '%d %b %y').strftime('%Y-%m-%d')
    renamed_df.loc[index, 'release_date'] = formatted_release_date

renamed_df
# Out:
#        rank                          game_name console  \
# 0         1                         God of War  Series
# 1         2                           Warriors  Series
# 2         3                      Devil May Cry  Series
# 3         4                   Dynasty Warriors  Series
# 4         5                 Grand Theft Auto V     PS3
# ...     ...                                ...     ...
# 58688   232      Nora, Princess, and Stray Cat      NS
# 58689   233        Memories Off: Innocent File      NS
# 58690   234   Enkan no Memoria: Kakera Tomoshi     PSV
# 58691   235                         Disorder 6    X360
# 58692   236  Zero Escape: Virtue's Last Reward     PSV
#
#                          publisher                developer  vgchartz_score  \
# 0      Sony Computer Entertainment  SIE Santa Monica Studio             NaN
# 1                             KOEI              Omega Force             NaN
# 2                           Capcom                   Capcom             NaN
# 3                          Unknown              Omega Force             NaN
# 4                   Rockstar Games           Rockstar North             NaN
# ...                            ...                      ...             ...
# 58688                     Harukaze                 Harukaze             NaN
# 58689                          5pb               5pb. Games             NaN
# 58690              Dramatic Create                  A'sRing             NaN
# 58691                          5pb               5pb. Games             NaN
# 58692                  Aksys Games                 ChunSoft             NaN
#
#        critic_score  user_score total_shipped global_sales na_sales pal_sales  \
# 0               NaN         NaN        51.00m          NaN      NaN       NaN
# 1               NaN         NaN        45.26m          NaN      NaN       NaN
# 2               NaN         NaN        22.00m          NaN      NaN       NaN
# 3               NaN         NaN        21.00m          NaN      NaN       NaN
# 4               9.4         NaN           NaN       20.32m    6.37m     9.85m
# ...             ...         ...           ...          ...      ...       ...
# 58688           NaN         NaN           NaN        0.00m      NaN       NaN
# 58689           NaN         NaN           NaN        0.00m      NaN       NaN
# 58690           NaN         NaN           NaN        0.00m      NaN       NaN
# 58691           NaN         NaN           NaN        0.00m      NaN       NaN
# 58692           NaN         NaN           NaN        0.00m      NaN     0.00m
#
#       japan_sales other_sales release_date         genre  release_year
# 0             NaN         NaN   2005-03-22        Action          2005
# 1             NaN         NaN   1997-06-30        Action          1997
# 2             NaN         NaN   2001-10-16        Action          2001
# 3             NaN         NaN          NaN        Action          <NA>
# 4           0.99m       3.12m   2013-09-17        Action          2013
# ...           ...         ...          ...           ...           ...
# 58688       0.00m         NaN   2018-10-25  Visual Novel          2018
# 58689       0.00m         NaN   2018-10-25  Visual Novel          2018
# 58690       0.00m         NaN   2018-03-29  Visual Novel          2018
# 58691       0.00m         NaN   2013-08-22  Visual Novel          2013
# 58692         NaN       0.00m   2012-10-23  Visual Novel          2012
#
# [22102 rows x 17 columns]

# %%
# Convert the release date data type to datetime64
renamed_df['release_date'] = renamed_df['release_date'].astype('datetime64[ns]')

# %%
# Confirm the release date data type to datetime64
renamed_df.dtypes
# Out:
# rank                       int64
# game_name                 object
# console                   object
# publisher                 object
# developer                 object
# vgchartz_score           float64
# critic_score             float64
# user_score               float64
# total_shipped             object
# global_sales              object
# na_sales                  object
# pal_sales                 object
# japan_sales               object
# other_sales               object
# release_date      datetime64[ns]
# genre                     object
# release_year               Int32
# dtype: object

# %%
# Check the release date column values
renamed_df
# Out:
#        rank                          game_name console  \
# 0         1                         God of War  Series
# 1         2                           Warriors  Series
# 2         3                      Devil May Cry  Series
# 3         4                   Dynasty Warriors  Series
# 4         5                 Grand Theft Auto V     PS3
# ...     ...                                ...     ...
# 58688   232      Nora, Princess, and Stray Cat      NS
# 58689   233        Memories Off: Innocent File      NS
# 58690   234   Enkan no Memoria: Kakera Tomoshi     PSV
# 58691   235                         Disorder 6    X360
# 58692   236  Zero Escape: Virtue's Last Reward     PSV
#
#                          publisher                developer  vgchartz_score  \
# 0      Sony Computer Entertainment  SIE Santa Monica Studio             NaN
# 1                             KOEI              Omega Force             NaN
# 2                           Capcom                   Capcom             NaN
# 3                          Unknown              Omega Force             NaN
# 4                   Rockstar Games           Rockstar North             NaN
# ...                            ...                      ...             ...
# 58688                     Harukaze                 Harukaze             NaN
# 58689                          5pb               5pb. Games             NaN
# 58690              Dramatic Create                  A'sRing             NaN
# 58691                          5pb               5pb. Games             NaN
# 58692                  Aksys Games                 ChunSoft             NaN
#
#        critic_score  user_score total_shipped global_sales na_sales pal_sales  \
# 0               NaN         NaN        51.00m          NaN      NaN       NaN
# 1               NaN         NaN        45.26m          NaN      NaN       NaN
# 2               NaN         NaN        22.00m          NaN      NaN       NaN
# 3               NaN         NaN        21.00m          NaN      NaN       NaN
# 4               9.4         NaN           NaN       20.32m    6.37m     9.85m
# ...             ...         ...           ...          ...      ...       ...
# 58688           NaN         NaN           NaN        0.00m      NaN       NaN
# 58689           NaN         NaN           NaN        0.00m      NaN       NaN
# 58690           NaN         NaN           NaN        0.00m      NaN       NaN
# 58691           NaN         NaN           NaN        0.00m      NaN       NaN
# 58692           NaN         NaN           NaN        0.00m      NaN     0.00m
#
#       japan_sales other_sales release_date         genre  release_year
# 0             NaN         NaN   2005-03-22        Action          2005
# 1             NaN         NaN   1997-06-30        Action          1997
# 2             NaN         NaN   2001-10-16        Action          2001
# 3             NaN         NaN          NaT        Action          <NA>
# 4           0.99m       3.12m   2013-09-17        Action          2013
# ...           ...         ...          ...           ...           ...
# 58688       0.00m         NaN   2018-10-25  Visual Novel          2018
# 58689       0.00m         NaN   2018-10-25  Visual Novel          2018
# 58690       0.00m         NaN   2018-03-29  Visual Novel          2018
# 58691       0.00m         NaN   2013-08-22  Visual Novel          2013
# 58692         NaN       0.00m   2012-10-23  Visual Novel          2012
#
# [22102 rows x 17 columns]

# %% [markdown]
# # Convert Sales values to Float format

# %%
# strip out character m from total_shipped column
for index, row in renamed_df.loc[renamed_df['total_shipped'].notna()].iterrows():
    total_shipped = row[8]
    renamed_df.loc[index, 'total_shipped'] = total_shipped[:-1]

renamed_df
# Out:
#        rank                          game_name console  \
# 0         1                         God of War  Series
# 1         2                           Warriors  Series
# 2         3                      Devil May Cry  Series
# 3         4                   Dynasty Warriors  Series
# 4         5                 Grand Theft Auto V     PS3
# ...     ...                                ...     ...
# 58688   232      Nora, Princess, and Stray Cat      NS
# 58689   233        Memories Off: Innocent File      NS
# 58690   234   Enkan no Memoria: Kakera Tomoshi     PSV
# 58691   235                         Disorder 6    X360
# 58692   236  Zero Escape: Virtue's Last Reward     PSV
#
#                          publisher                developer  vgchartz_score  \
# 0      Sony Computer Entertainment  SIE Santa Monica Studio             NaN
# 1                             KOEI              Omega Force             NaN
# 2                           Capcom                   Capcom             NaN
# 3                          Unknown              Omega Force             NaN
# 4                   Rockstar Games           Rockstar North             NaN
# ...                            ...                      ...             ...
# 58688                     Harukaze                 Harukaze             NaN
# 58689                          5pb               5pb. Games             NaN
# 58690              Dramatic Create                  A'sRing             NaN
# 58691                          5pb               5pb. Games             NaN
# 58692                  Aksys Games                 ChunSoft             NaN
#
#        critic_score  user_score total_shipped global_sales na_sales pal_sales  \
# 0               NaN         NaN         51.00          NaN      NaN       NaN
# 1               NaN         NaN         45.26          NaN      NaN       NaN
# 2               NaN         NaN         22.00          NaN      NaN       NaN
# 3               NaN         NaN         21.00          NaN      NaN       NaN
# 4               9.4         NaN           NaN       20.32m    6.37m     9.85m
# ...             ...         ...           ...          ...      ...       ...
# 58688           NaN         NaN           NaN        0.00m      NaN       NaN
# 58689           NaN         NaN           NaN        0.00m      NaN       NaN
# 58690           NaN         NaN           NaN        0.00m      NaN       NaN
# 58691           NaN         NaN           NaN        0.00m      NaN       NaN
# 58692           NaN         NaN           NaN        0.00m      NaN     0.00m
#
#       japan_sales other_sales release_date         genre  release_year
# 0             NaN         NaN   2005-03-22        Action          2005
# 1             NaN         NaN   1997-06-30        Action          1997
# 2             NaN         NaN   2001-10-16        Action          2001
# 3             NaN         NaN          NaT        Action          <NA>
# 4           0.99m       3.12m   2013-09-17        Action          2013
# ...           ...         ...          ...           ...           ...
# 58688       0.00m         NaN   2018-10-25  Visual Novel          2018
# 58689       0.00m         NaN   2018-10-25  Visual Novel          2018
# 58690       0.00m         NaN   2018-03-29  Visual Novel          2018
# 58691       0.00m         NaN   2013-08-22  Visual Novel          2013
# 58692         NaN       0.00m   2012-10-23  Visual Novel          2012
#
# [22102 rows x 17 columns]

# %%
# strip out character m from global_sales column
for index, row in renamed_df.loc[renamed_df['global_sales'].notna()].iterrows():
    global_sales = row[9]
    renamed_df.loc[index, 'global_sales'] = global_sales[:-1]

renamed_df
# Out:
#        rank                          game_name console  \
# 0         1                         God of War  Series
# 1         2                           Warriors  Series
# 2         3                      Devil May Cry  Series
# 3         4                   Dynasty Warriors  Series
# 4         5                 Grand Theft Auto V     PS3
# ...     ...                                ...     ...
# 58688   232      Nora, Princess, and Stray Cat      NS
# 58689   233        Memories Off: Innocent File      NS
# 58690   234   Enkan no Memoria: Kakera Tomoshi     PSV
# 58691   235                         Disorder 6    X360
# 58692   236  Zero Escape: Virtue's Last Reward     PSV
#
#                          publisher                developer  vgchartz_score  \
# 0      Sony Computer Entertainment  SIE Santa Monica Studio             NaN
# 1                             KOEI              Omega Force             NaN
# 2                           Capcom                   Capcom             NaN
# 3                          Unknown              Omega Force             NaN
# 4                   Rockstar Games           Rockstar North             NaN
# ...                            ...                      ...             ...
# 58688                     Harukaze                 Harukaze             NaN
# 58689                          5pb               5pb. Games             NaN
# 58690              Dramatic Create                  A'sRing             NaN
# 58691                          5pb               5pb. Games             NaN
# 58692                  Aksys Games                 ChunSoft             NaN
#
#        critic_score  user_score total_shipped global_sales na_sales pal_sales  \
# 0               NaN         NaN         51.00          NaN      NaN       NaN
# 1               NaN         NaN         45.26          NaN      NaN       NaN
# 2               NaN         NaN         22.00          NaN      NaN       NaN
# 3               NaN         NaN         21.00          NaN      NaN       NaN
# 4               9.4         NaN           NaN        20.32    6.37m     9.85m
# ...             ...         ...           ...          ...      ...       ...
# 58688           NaN         NaN           NaN         0.00      NaN       NaN
# 58689           NaN         NaN           NaN         0.00      NaN       NaN
# 58690           NaN         NaN           NaN         0.00      NaN       NaN
# 58691           NaN         NaN           NaN         0.00      NaN       NaN
# 58692           NaN         NaN           NaN         0.00      NaN     0.00m
#
#       japan_sales other_sales release_date         genre  release_year
# 0             NaN         NaN   2005-03-22        Action          2005
# 1             NaN         NaN   1997-06-30        Action          1997
# 2             NaN         NaN   2001-10-16        Action          2001
# 3             NaN         NaN          NaT        Action          <NA>
# 4           0.99m       3.12m   2013-09-17        Action          2013
# ...           ...         ...          ...           ...           ...
# 58688       0.00m         NaN   2018-10-25  Visual Novel          2018
# 58689       0.00m         NaN   2018-10-25  Visual Novel          2018
# 58690       0.00m         NaN   2018-03-29  Visual Novel          2018
# 58691       0.00m         NaN   2013-08-22  Visual Novel          2013
# 58692         NaN       0.00m   2012-10-23  Visual Novel          2012
#
# [22102 rows x 17 columns]

# %%
# strip out character m from na_sales column
for index, row in renamed_df.loc[renamed_df['na_sales'].notna()].iterrows():
    na_sales = row[10]
    renamed_df.loc[index, 'na_sales'] = na_sales[:-1]

renamed_df
# Out:
#        rank                          game_name console  \
# 0         1                         God of War  Series
# 1         2                           Warriors  Series
# 2         3                      Devil May Cry  Series
# 3         4                   Dynasty Warriors  Series
# 4         5                 Grand Theft Auto V     PS3
# ...     ...                                ...     ...
# 58688   232      Nora, Princess, and Stray Cat      NS
# 58689   233        Memories Off: Innocent File      NS
# 58690   234   Enkan no Memoria: Kakera Tomoshi     PSV
# 58691   235                         Disorder 6    X360
# 58692   236  Zero Escape: Virtue's Last Reward     PSV
#
#                          publisher                developer  vgchartz_score  \
# 0      Sony Computer Entertainment  SIE Santa Monica Studio             NaN
# 1                             KOEI              Omega Force             NaN
# 2                           Capcom                   Capcom             NaN
# 3                          Unknown              Omega Force             NaN
# 4                   Rockstar Games           Rockstar North             NaN
# ...                            ...                      ...             ...
# 58688                     Harukaze                 Harukaze             NaN
# 58689                          5pb               5pb. Games             NaN
# 58690              Dramatic Create                  A'sRing             NaN
# 58691                          5pb               5pb. Games             NaN
# 58692                  Aksys Games                 ChunSoft             NaN
#
#        critic_score  user_score total_shipped global_sales na_sales pal_sales  \
# 0               NaN         NaN         51.00          NaN      NaN       NaN
# 1               NaN         NaN         45.26          NaN      NaN       NaN
# 2               NaN         NaN         22.00          NaN      NaN       NaN
# 3               NaN         NaN         21.00          NaN      NaN       NaN
# 4               9.4         NaN           NaN        20.32     6.37     9.85m
# ...             ...         ...           ...          ...      ...       ...
# 58688           NaN         NaN           NaN         0.00      NaN       NaN
# 58689           NaN         NaN           NaN         0.00      NaN       NaN
# 58690           NaN         NaN           NaN         0.00      NaN       NaN
# 58691           NaN         NaN           NaN         0.00      NaN       NaN
# 58692           NaN         NaN           NaN         0.00      NaN     0.00m
#
#       japan_sales other_sales release_date         genre  release_year
# 0             NaN         NaN   2005-03-22        Action          2005
# 1             NaN         NaN   1997-06-30        Action          1997
# 2             NaN         NaN   2001-10-16        Action          2001
# 3             NaN         NaN          NaT        Action          <NA>
# 4           0.99m       3.12m   2013-09-17        Action          2013
# ...           ...         ...          ...           ...           ...
# 58688       0.00m         NaN   2018-10-25  Visual Novel          2018
# 58689       0.00m         NaN   2018-10-25  Visual Novel          2018
# 58690       0.00m         NaN   2018-03-29  Visual Novel          2018
# 58691       0.00m         NaN   2013-08-22  Visual Novel          2013
# 58692         NaN       0.00m   2012-10-23  Visual Novel          2012
#
# [22102 rows x 17 columns]

# %%
# strip out character m from pal_sales column
for index, row in renamed_df.loc[renamed_df['pal_sales'].notna()].iterrows():
    pal_sales = row[11]
    renamed_df.loc[index, 'pal_sales'] = pal_sales[:-1]

renamed_df
# Out:
#        rank                          game_name console  \
# 0         1                         God of War  Series
# 1         2                           Warriors  Series
# 2         3                      Devil May Cry  Series
# 3         4                   Dynasty Warriors  Series
# 4         5                 Grand Theft Auto V     PS3
# ...     ...                                ...     ...
# 58688   232      Nora, Princess, and Stray Cat      NS
# 58689   233        Memories Off: Innocent File      NS
# 58690   234   Enkan no Memoria: Kakera Tomoshi     PSV
# 58691   235                         Disorder 6    X360
# 58692   236  Zero Escape: Virtue's Last Reward     PSV
#
#                          publisher                developer  vgchartz_score  \
# 0      Sony Computer Entertainment  SIE Santa Monica Studio             NaN
# 1                             KOEI              Omega Force             NaN
# 2                           Capcom                   Capcom             NaN
# 3                          Unknown              Omega Force             NaN
# 4                   Rockstar Games           Rockstar North             NaN
# ...                            ...                      ...             ...
# 58688                     Harukaze                 Harukaze             NaN
# 58689                          5pb               5pb. Games             NaN
# 58690              Dramatic Create                  A'sRing             NaN
# 58691                          5pb               5pb. Games             NaN
# 58692                  Aksys Games                 ChunSoft             NaN
#
#        critic_score  user_score total_shipped global_sales na_sales pal_sales  \
# 0               NaN         NaN         51.00          NaN      NaN       NaN
# 1               NaN         NaN         45.26          NaN      NaN       NaN
# 2               NaN         NaN         22.00          NaN      NaN       NaN
# 3               NaN         NaN         21.00          NaN      NaN       NaN
# 4               9.4         NaN           NaN        20.32     6.37      9.85
# ...             ...         ...           ...          ...      ...       ...
# 58688           NaN         NaN           NaN         0.00      NaN       NaN
# 58689           NaN         NaN           NaN         0.00      NaN       NaN
# 58690           NaN         NaN           NaN         0.00      NaN       NaN
# 58691           NaN         NaN           NaN         0.00      NaN       NaN
# 58692           NaN         NaN           NaN         0.00      NaN      0.00
#
#       japan_sales other_sales release_date         genre  release_year
# 0             NaN         NaN   2005-03-22        Action          2005
# 1             NaN         NaN   1997-06-30        Action          1997
# 2             NaN         NaN   2001-10-16        Action          2001
# 3             NaN         NaN          NaT        Action          <NA>
# 4           0.99m       3.12m   2013-09-17        Action          2013
# ...           ...         ...          ...           ...           ...
# 58688       0.00m         NaN   2018-10-25  Visual Novel          2018
# 58689       0.00m         NaN   2018-10-25  Visual Novel          2018
# 58690       0.00m         NaN   2018-03-29  Visual Novel          2018
# 58691       0.00m         NaN   2013-08-22  Visual Novel          2013
# 58692         NaN       0.00m   2012-10-23  Visual Novel          2012
#
# [22102 rows x 17 columns]

# %%
# strip out character m from japan_sales column
for index, row in renamed_df.loc[renamed_df['japan_sales'].notna()].iterrows():
    japan_sales = row[12]
    renamed_df.loc[index, 'japan_sales'] = japan_sales[:-1]

renamed_df
# Out:
#        rank                          game_name console  \
# 0         1                         God of War  Series
# 1         2                           Warriors  Series
# 2         3                      Devil May Cry  Series
# 3         4                   Dynasty Warriors  Series
# 4         5                 Grand Theft Auto V     PS3
# ...     ...                                ...     ...
# 58688   232      Nora, Princess, and Stray Cat      NS
# 58689   233        Memories Off: Innocent File      NS
# 58690   234   Enkan no Memoria: Kakera Tomoshi     PSV
# 58691   235                         Disorder 6    X360
# 58692   236  Zero Escape: Virtue's Last Reward     PSV
#
#                          publisher                developer  vgchartz_score  \
# 0      Sony Computer Entertainment  SIE Santa Monica Studio             NaN
# 1                             KOEI              Omega Force             NaN
# 2                           Capcom                   Capcom             NaN
# 3                          Unknown              Omega Force             NaN
# 4                   Rockstar Games           Rockstar North             NaN
# ...                            ...                      ...             ...
# 58688                     Harukaze                 Harukaze             NaN
# 58689                          5pb               5pb. Games             NaN
# 58690              Dramatic Create                  A'sRing             NaN
# 58691                          5pb               5pb. Games             NaN
# 58692                  Aksys Games                 ChunSoft             NaN
#
#        critic_score  user_score total_shipped global_sales na_sales pal_sales  \
# 0               NaN         NaN         51.00          NaN      NaN       NaN
# 1               NaN         NaN         45.26          NaN      NaN       NaN
# 2               NaN         NaN         22.00          NaN      NaN       NaN
# 3               NaN         NaN         21.00          NaN      NaN       NaN
# 4               9.4         NaN           NaN        20.32     6.37      9.85
# ...             ...         ...           ...          ...      ...       ...
# 58688           NaN         NaN           NaN         0.00      NaN       NaN
# 58689           NaN         NaN           NaN         0.00      NaN       NaN
# 58690           NaN         NaN           NaN         0.00      NaN       NaN
# 58691           NaN         NaN           NaN         0.00      NaN       NaN
# 58692           NaN         NaN           NaN         0.00      NaN      0.00
#
#       japan_sales other_sales release_date         genre  release_year
# 0             NaN         NaN   2005-03-22        Action          2005
# 1             NaN         NaN   1997-06-30        Action          1997
# 2             NaN         NaN   2001-10-16        Action          2001
# 3             NaN         NaN          NaT        Action          <NA>
# 4            0.99       3.12m   2013-09-17        Action          2013
# ...           ...         ...          ...           ...           ...
# 58688        0.00         NaN   2018-10-25  Visual Novel          2018
# 58689        0.00         NaN   2018-10-25  Visual Novel          2018
# 58690        0.00         NaN   2018-03-29  Visual Novel          2018
# 58691        0.00         NaN   2013-08-22  Visual Novel          2013
# 58692         NaN       0.00m   2012-10-23  Visual Novel          2012
#
# [22102 rows x 17 columns]

# %%
# strip out character m from other_sales column
for index, row in renamed_df.loc[renamed_df['other_sales'].notna()].iterrows():
    other_sales = row[13]
    renamed_df.loc[index, 'other_sales'] = other_sales[:-1]

renamed_df
# Out:
#        rank                          game_name console  \
# 0         1                         God of War  Series
# 1         2                           Warriors  Series
# 2         3                      Devil May Cry  Series
# 3         4                   Dynasty Warriors  Series
# 4         5                 Grand Theft Auto V     PS3
# ...     ...                                ...     ...
# 58688   232      Nora, Princess, and Stray Cat      NS
# 58689   233        Memories Off: Innocent File      NS
# 58690   234   Enkan no Memoria: Kakera Tomoshi     PSV
# 58691   235                         Disorder 6    X360
# 58692   236  Zero Escape: Virtue's Last Reward     PSV
#
#                          publisher                developer  vgchartz_score  \
# 0      Sony Computer Entertainment  SIE Santa Monica Studio             NaN
# 1                             KOEI              Omega Force             NaN
# 2                           Capcom                   Capcom             NaN
# 3                          Unknown              Omega Force             NaN
# 4                   Rockstar Games           Rockstar North             NaN
# ...                            ...                      ...             ...
# 58688                     Harukaze                 Harukaze             NaN
# 58689                          5pb               5pb. Games             NaN
# 58690              Dramatic Create                  A'sRing             NaN
# 58691                          5pb               5pb. Games             NaN
# 58692                  Aksys Games                 ChunSoft             NaN
#
#        critic_score  user_score total_shipped global_sales na_sales pal_sales  \
# 0               NaN         NaN         51.00          NaN      NaN       NaN
# 1               NaN         NaN         45.26          NaN      NaN       NaN
# 2               NaN         NaN         22.00          NaN      NaN       NaN
# 3               NaN         NaN         21.00          NaN      NaN       NaN
# 4               9.4         NaN           NaN        20.32     6.37      9.85
# ...             ...         ...           ...          ...      ...       ...
# 58688           NaN         NaN           NaN         0.00      NaN       NaN
# 58689           NaN         NaN           NaN         0.00      NaN       NaN
# 58690           NaN         NaN           NaN         0.00      NaN       NaN
# 58691           NaN         NaN           NaN         0.00      NaN       NaN
# 58692           NaN         NaN           NaN         0.00      NaN      0.00
#
#       japan_sales other_sales release_date         genre  release_year
# 0             NaN         NaN   2005-03-22        Action          2005
# 1             NaN         NaN   1997-06-30        Action          1997
# 2             NaN         NaN   2001-10-16        Action          2001
# 3             NaN         NaN          NaT        Action          <NA>
# 4            0.99        3.12   2013-09-17        Action          2013
# ...           ...         ...          ...           ...           ...
# 58688        0.00         NaN   2018-10-25  Visual Novel          2018
# 58689        0.00         NaN   2018-10-25  Visual Novel          2018
# 58690        0.00         NaN   2018-03-29  Visual Novel          2018
# 58691        0.00         NaN   2013-08-22  Visual Novel          2013
# 58692         NaN        0.00   2012-10-23  Visual Novel          2012
#
# [22102 rows x 17 columns]

# %%
# Checking to see data types
renamed_df.dtypes
# Out:
# rank                       int64
# game_name                 object
# console                   object
# publisher                 object
# developer                 object
# vgchartz_score           float64
# critic_score             float64
# user_score               float64
# total_shipped             object
# global_sales              object
# na_sales                  object
# pal_sales                 object
# japan_sales               object
# other_sales               object
# release_date      datetime64[ns]
# genre                     object
# release_year               Int32
# dtype: object

# %%
# Convert all sales columns to float data type
renamed_df['total_shipped'] = renamed_df['total_shipped'].astype('float')
renamed_df['global_sales'] = renamed_df['global_sales'].astype('float')
renamed_df['na_sales'] = renamed_df['na_sales'].astype('float')
renamed_df['pal_sales'] = renamed_df['pal_sales'].astype('float')
renamed_df['japan_sales'] = renamed_df['japan_sales'].astype('float')
renamed_df['other_sales'] = renamed_df['other_sales'].astype('float')

# %%
# Confirm all sales columns are float data type
renamed_df.dtypes
# Out:
# rank                       int64
# game_name                 object
# console                   object
# publisher                 object
# developer                 object
# vgchartz_score           float64
# critic_score             float64
# user_score               float64
# total_shipped            float64
# global_sales             float64
# na_sales                 float64
# pal_sales                float64
# japan_sales              float64
# other_sales              float64
# release_date      datetime64[ns]
# genre                     object
# release_year               Int32
# dtype: object

# %% [markdown]
# # Load transformed data to csv file

# %%
# Set csv file path
csv_file_path = os.path.join('Output', 'Transformed_video_games_data.csv')

# %%
# load transformed data to csv file
renamed_df.to_csv(csv_file_path, index=False)
